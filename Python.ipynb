# %%
import datetime

# Get the current date and time

now = datetime.datetime.now()
print("Current date and time:",now)
# Out:
# Current date and time: 2025-04-01 19:14:17.183512

# %%
import datetime

# Get the current date and time

now = datetime.datetime.now()
print("Current date and time:",now)
# Out:
# Current date and time: 2025-04-01 19:14:26.102342

# %%
# Get the current date
today = datetime.date.today()
print("Current date:", today)
# Out:
# Current date: 2025-04-01

# %%
# Get the current time
current_time = datetime.datetime.now().time()
print("Current time:", current_time)
# Out:
# Current time: 19:22:58.444330

# %%
import datetime

# Create a date object
date_obj = datetime.date(2025, 4, 2)
print("Date object:", date_obj)
# Out:
# Date object: 2025-04-02
